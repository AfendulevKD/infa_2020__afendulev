# %%
import pygame
from pygame.draw import *

pygame.init()

n=0.5
FPS = 30
screen = pygame.display.set_mode((round(794*n), round(1123*n)))


rect(screen, (183, 196, 200), (0*n,0*n, 794*n, 1123*n), )
rect(screen, (83, 108, 103), (0*n,690*n, 794*n, 433*n), )

rect(screen, (219, 227, 226), (594*n,20*n, 180*n, 770*n), )
rect(screen, (147, 167, 172), (20*n,20*n, 180*n, 770*n), )
rect(screen, (147, 172, 167), (230*n,60*n, 180*n, 730*n), )
rect(screen, (183, 200, 196), (150*n,160*n, 180*n, 730*n), )
rect(screen, (107, 130, 130), (500*n,120*n, 180*n, 770*n), )

circle(screen, (183, 200, 196), (round(500*n), round(2000*n)), round(1050*n))

rect(screen, (0, 204, 255), (270*n,1000*n, 400*n, 75*n), )
rect(screen, (0, 204, 255), (350*n,950*n, 200*n, 60*n), )
circle(screen, (0, 0, 0), (round(350*n), round(1065*n)), round(40*n))
circle(screen, (0, 0, 0), (round(600*n), round(1065*n)), round(40*n))
rect(screen, (213, 246, 255), (370*n,960*n, 70*n, 40*n), )
rect(screen, (213, 246, 255), (460*n,960*n, 70*n, 40*n), )
rect(screen, (0, 0, 0), (250*n,1050*n, 20*n, 10*n), )
BLACK = (0, 0, 0)
screen.set_colorkey(BLACK)
screen.set_alpha(255)
ellipse(screen,(168,178,188) , (0*n, 1000*n, 280*n, 100*n))


s = pygame.Surface([640,480], pygame.SRCALPHA, 32)
s= s.conver_alpha()
s.set_alpha(100)
pygame.draw.circle(s, (200, 200, 200), (150, 150), 50)
screen.blit(s, (0, 0))




pygame.display.update()
clock = pygame.time.Clock()
finished = False

while not finished:
    clock.tick(FPS)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            finished = True

pygame.quit()
# Out:
# <ipython-input-23-9f15891aafe7>:11: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (183, 196, 200), (0*n,0*n, 794*n, 1123*n), )
# <ipython-input-23-9f15891aafe7>:12: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (83, 108, 103), (0*n,690*n, 794*n, 433*n), )
# <ipython-input-23-9f15891aafe7>:14: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (219, 227, 226), (594*n,20*n, 180*n, 770*n), )
# ...

# %%
import pygame
from pygame.draw import *

pygame.init()

n=0.5
FPS = 30
screen = pygame.display.set_mode((round(794*n), round(1123*n)))


rect(screen, (183, 196, 200), (0*n,0*n, 794*n, 1123*n), )
rect(screen, (83, 108, 103), (0*n,690*n, 794*n, 433*n), )

rect(screen, (219, 227, 226), (594*n,20*n, 180*n, 770*n), )
rect(screen, (147, 167, 172), (20*n,20*n, 180*n, 770*n), )
rect(screen, (147, 172, 167), (230*n,60*n, 180*n, 730*n), )
rect(screen, (183, 200, 196), (150*n,160*n, 180*n, 730*n), )
rect(screen, (107, 130, 130), (500*n,120*n, 180*n, 770*n), )

circle(screen, (183, 200, 196), (round(500*n), round(2000*n)), round(1050*n))

rect(screen, (0, 204, 255), (270*n,1000*n, 400*n, 75*n), )
rect(screen, (0, 204, 255), (350*n,950*n, 200*n, 60*n), )
circle(screen, (0, 0, 0), (round(350*n), round(1065*n)), round(40*n))
circle(screen, (0, 0, 0), (round(600*n), round(1065*n)), round(40*n))
rect(screen, (213, 246, 255), (370*n,960*n, 70*n, 40*n), )
rect(screen, (213, 246, 255), (460*n,960*n, 70*n, 40*n), )
rect(screen, (0, 0, 0), (250*n,1050*n, 20*n, 10*n), )
BLACK = (0, 0, 0)
screen.set_colorkey(BLACK)
screen.set_alpha(255)
ellipse(screen,(168,178,188) , (0*n, 1000*n, 280*n, 100*n))


s = pygame.Surface((640,480))

s.set_alpha(100)
pygame.draw.circle(s, (150, 150, 150), (150, 150), 50)
screen.blit(s, (0, 0))




pygame.display.update()
clock = pygame.time.Clock()
finished = False

while not finished:
    clock.tick(FPS)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            finished = True

pygame.quit()
# Out:
# <ipython-input-36-972de648f005>:11: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (183, 196, 200), (0*n,0*n, 794*n, 1123*n), )
# <ipython-input-36-972de648f005>:12: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (83, 108, 103), (0*n,690*n, 794*n, 433*n), )
# <ipython-input-36-972de648f005>:14: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (219, 227, 226), (594*n,20*n, 180*n, 770*n), )
# ...

# %%
import pygame
from pygame.draw import *

def sm(x1, dx1):
    return 1588-x1-dx1
def sma(x3,dx3):
    return 400-x3-dx3

def avto(x2,y2,size):
    rect(screen, (0, 204, 255), (x2*n,y2*n, 400*n*size, 75*n*size), )
    rect(screen, (0, 204, 255), (((x2+80*size)*n),(y2-50*size)*n, 200*n*size, 60*n*size), )
    circle(screen, (0, 0, 0), (round((x2+80*size)*n), round((y2+65*size)*n)), round(40*n*size))
    circle(screen, (0, 0, 0), (round((x2+330*size)*n), round((y2+65*size)*n)), round(40*n*size))
    rect(screen, (213, 246, 255), ((x2+180*size)*n,(y2-40*size)*n, 70*n*size, 40*n*size), )
    rect(screen, (213, 246, 255), ((x2+100*size)*n,(y2-40*size)*n, 70*n*size, 40*n*size), )
    rect(screen, (0, 0, 0), ((x2-20*size)*n,(y2+50*size)*n, 20*n*size, 10*n*size), )
def avtoREV(x2,y2,size):
    rect(screen, (0, 204, 255), (x2*n,y2*n, 400*n*size, 75*n*size), )
    rect(screen, (0, 204, 255), (((x2+sma(80,200)*size)*n),(y2-50*size)*n, 200*n*size, 60*n*size), )
    circle(screen, (0, 0, 0), (round((x2+sma(80,0)*size)*n), round((y2+65*size)*n)), round(40*n*size))
    circle(screen, (0, 0, 0), (round((x2+sma(330,0)*size)*n), round((y2+65*size)*n)), round(40*n*size))
    rect(screen, (213, 246, 255), ((x2+sma(180,70)*size)*n,(y2-40*size)*n, 70*n*size, 40*n*size), )
    rect(screen, (213, 246, 255), ((x2+sma(100,70)*size)*n,(y2-40*size)*n, 70*n*size, 40*n*size), )
    rect(screen, (0, 0, 0), ((x2+sma(-20,20)*size)*n,(y2+50*size)*n, 20*n*size, 10*n*size), )




    
pygame.init()

n=0.5
FPS = 30
screen = pygame.display.set_mode((round(794*2*n), round(1123*n)))


rect(screen, (183, 196, 200), (0*n,0*n, 794*n, 1123*n), )
rect(screen, (83, 108, 103), (0*n,690*n, 794*n, 433*n), )

rect(screen, (219, 227, 226), (594*n,20*n, 180*n, 770*n), )
rect(screen, (147, 167, 172), (20*n,20*n, 180*n, 770*n), )
rect(screen, (147, 172, 167), (230*n,60*n, 180*n, 730*n), )
rect(screen, (183, 200, 196), (150*n,160*n, 180*n, 730*n), )
rect(screen, (107, 130, 130), (500*n,120*n, 180*n, 770*n), )








1111111111
a=794
rect(screen, (183, 196, 200), (794*n,0*n, 794*n, 1123*n), )
rect(screen, (83, 108, 103), (794*n,690*n, 794*n, 433*n), )

rect(screen, (219, 227, 226), (sm(594,180)*n,20*n, 180*n, 770*n), )
rect(screen, (147, 167, 172), (sm(20,180)*n,20*n, 180*n, 770*n), )
rect(screen, (147, 172, 167), (sm(230,180)*n,60*n, 180*n, 730*n), )
rect(screen, (183, 200, 196), (sm(150,180)*n,160*n, 180*n, 730*n), )
rect(screen, (107, 130, 130), (sm(500,180)*n,120*n, 180*n, 770*n), )


avtoREV(1400,900,0.5)
avtoREV(100,900,0.5)
avtoREV(1000,900,0.5)
avtoREV(650,900,0.5)
avto(272,1000,1)
avto(1000,1000,1)
avto(-300,1000,1)





111111111111111

pygame.display.update()
clock = pygame.time.Clock()
finished = False

while not finished:
    clock.tick(FPS)
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            finished = True

pygame.quit()
# Out:
# <ipython-input-37-32cfaff865dc>:37: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (183, 196, 200), (0*n,0*n, 794*n, 1123*n), )
# <ipython-input-37-32cfaff865dc>:38: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (83, 108, 103), (0*n,690*n, 794*n, 433*n), )
# <ipython-input-37-32cfaff865dc>:40: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   rect(screen, (219, 227, 226), (594*n,20*n, 180*n, 770*n), )
# ...

# %%
# Out:
# 2
